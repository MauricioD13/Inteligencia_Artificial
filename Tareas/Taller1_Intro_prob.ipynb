# %% [markdown]
# # Taller en clase #1
# ## Autor: Mauricio David Cuello
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=1000
m=30
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %% [markdown]
# # Bernoulli

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.308 var_est= 0.21313599999999996

# %% [markdown]
# # Binomial
# ### Variable aleatoria

# %%
# binomial con cierto p entre 0 y 1 y cierto n
from scipy.stats import binom
n,p = 10, 0.5
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
bi = binom.rvs(n, p, size=N)
plt.plot(bi)
plt.title(str(N)+" puntos distribuidos binomial con p="+str(p)+ " y n="+str(n))
plt.show()

# %% [markdown]
# ## Datos ordenados

# %%
bi.sort()
plt.plot(bi)
plt.title(str(N)+" puntos distribuidos binomial ordenados con p="+str(p))
plt.show()

# %%
print(f"Valores teóricos media y varianza: {mean} , {var}")
# Out:
# Valores teóricos media y varianza: 5.0 , 2.5

# %%
plt.hist(bi, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=bi.mean()
varest=bi.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 5.0 var_est= 2.696

# %% [markdown]
# # Geometrica
# ### Variable aleatoria

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom
n,p = 10, 0.5
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
geo = geom.rvs(p, size=N)
plt.plot(geo)
plt.title(str(N)+" puntos distribuidos geometrica con p="+str(p))
plt.show()

# %% [markdown]
# ## Datos ordenados e histograma

# %%
geo.sort()
plt.plot(geo)
plt.title(str(N)+" puntos distribuidos geometrica ordenados con p="+str(p))
plt.show()

# %%
plt.hist(geo, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometrica con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=geo.mean()
varest=geo.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 2.0 var= 2.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 2.016 var_est= 2.0277439999999998

# %% [markdown]
# # Poisson
# ## Variable Aleatoria

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
n,p = 10, 0.5
mean, var, skew, kurt = poisson.stats(p, moments='mvsk')
pois= poisson.rvs(L, size=N)
plt.plot(pois)
plt.title(str(N)+" puntos distribuidos binomial con p="+str(p))
plt.show()

# %%
geo.sort()
plt.plot(geo)
plt.title(str(N)+" puntos distribuidos binomial ordenados con p="+str(p))
plt.show()

# %%
plt.hist(geo, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=bi.mean()
varest=bi.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 0.5 var= 0.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 5.0 var_est= 2.696

# %% [markdown]
# # Binomial Negativa
# ## Variable Aleatoria

# %%
#Binomial negativa con parametro p después de r fallos
r,p = 5,0.5
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(r, p, moments='mvsk')
nbi = nbinom.rvs(r ,p , size=N)
plt.plot(nbi)
plt.title(str(N)+" puntos distribuidos binomial negativa con p="+str(p))
plt.show()

# %%
nbi.sort()
plt.plot(nbi)
plt.title(str(N)+" puntos distribuidos binomial negativa ordenados con p="+str(p))
plt.show()

# %%
plt.hist(nbi, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=nbi.mean()
varest=nbi.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'int'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 4.986 var_est= 9.567804

# %% [markdown]
# # Segundo punto: Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=1000
m=30
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %% [markdown]
# # Normal

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con media="+str(u)+" y desviacion estandar= "+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 5.020866955775235 var_est= 0.2493526869507828

# %%
# Uniforme entre 0 y 255

# %% [markdown]
# # T Student

# %%
#T de Student con paramero K 
from scipy.stats import t
K=1.0
mean, var, skew, kurt = t.stats(moments='mvsk',df=K)
u=mean
std=var
r = t.rvs (df=K, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t con media="+str(u)+" y var="+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t ordenados con media="+str(u)+" y var="+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos t con u="+str(u)+ " y var= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= inf var= nan
# Los valores estimados en nuestro experimento de la media y varianza son u_est= -0.40635256271250225 var_est= 2884.761791740032

# %% [markdown]
# # Exponencial

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import expon
mean, var, skew, kurt = expon.stats(moments='mvsk')
expo = expon.rvs (size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(expo)
plt.title(str(N)+" puntos distribuidos exponecial con media="+str(mean))
plt.show()

# %%
expo.sort()
plt.plot(expo)
plt.title(str(N)+" puntos distribuidos exponencial ordenados con Lambda="+str(L))
plt.show()

# %%
plt.hist(expo, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencial con Lamda="+str(L))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(expo))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=expo.mean()
varest=expo.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 1.0 var= 1.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.0302838759905408 var_est= 1.0044311778396877

# %% [markdown]
# # Chi cuadrada

# %%
#Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2
mean, var, skew, kurt = chi2.stats(K, moments='mvsk')
c2 = chi2.rvs (K, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(c2)
plt.title(str(N)+" puntos distribuidos chi cuadrada con media="+str(mean)+" y varianza="+str(var))
plt.show()

# %%
c2.sort()
plt.plot(c2)
plt.title(str(N)+" puntos distribuidos chi cuadrada ordenados con K="+str(K))
plt.show()

# %%
plt.hist(c2, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadrada con media="+str(mean)+ " y varianza= "+str(var))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=c2.mean()
varest=c2.var()
print("Los valores teoricos de la media y varianza para la chi cuadrada son mean=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la chi cuadrada son mean= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 3.042082254390659 var_est= 6.159947654092523

# %% [markdown]
# # Gamma

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
from scipy.stats import gengamma
mean, var, skew, kurt = gengamma.stats(k, t, moments='mvsk')
# Use gengamma porque habia dos parametros y en la documentacion dice que la funcion gamma tiene solo un parametro
ggam = gengamma.rvs (k, t, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(ggam)
plt.title(str(N)+" puntos distribuidos gamma con media="+str(mean)+" y varianza="+str(var))
plt.show()

# %%
ggam.sort()
plt.plot(ggam)
plt.title(str(N)+" puntos distribuidos gamma ordenados con theta="+str(t))
plt.show()

# %%
plt.hist(ggam, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma con media="+str(mean)+ " y varianza= "+str(var))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(ggam))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=ggam.mean()
varest=ggam.var()
print("Los valores teoricos de la media y varianza para la gamma son mean=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la gamma son mean= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 14.148253918441617 var_est= 698.6565628567238

# %% [markdown]
# # Conclusiones
# En todas las distribuciones sin importar si es continua o discreta, se generan algunas
# estadísticas con el método '.stats'. Posteriormente se generan las variables aleatorias con el método '.rvs' de cada distribución y se toman los una cierta cantidad de puntos. Luego se ordenan para generar un histograma que lleva la forma de la distribución en cuestion
